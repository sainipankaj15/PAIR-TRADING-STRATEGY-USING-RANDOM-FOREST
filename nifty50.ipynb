          'Intraday_3_RF_k_6' : [0.007227575987108938, 0.008292873610262274, 0.006367287966233795, 0.004019112507826519, 0.003803414775465231, 0.003930644797003442, 0.0020910703672505594],
          'Intraday_3_RF_k_7' : [0.00680254165467636, 0.0077061388050372465, 0.005667321255504921, 0.003981164731902257, 0.00348225919382645, 0.0038568804408863322, 0.002104332904427151],
          'Intraday_3_RF_k_8' : [0.006629266690819306, 0.0070885504419748, 0.005548116447567735, 0.0041112220751055705, 0.003227923643696409, 0.0035697905931137276, 0.002086027916415807],


          'IntraDay_4_RF_k_5':[0.008041819307572792, 0.00806452477206845, 0.005611378046177217, 0.004485801904527236, 0.004090819514838318, 0.003517805746139194, 0.0020613776072041265]
          }

# %%
df=pd.DataFrame.from_dict(new_data);

# %%
df = df.rename(columns={'Number ': 'Number'})

# %%
df
# Out:
#    year  IntraDay_1_RF_k_5  NextDay_1_RF_k_5  IntraDay_2_RF_A_k_1  \
# 0  2013           0.002695          0.002710             0.010770
# 1  2014           0.002214          0.002082             0.012115
# 2  2015           0.000957          0.001248             0.011375
# 3  2016           0.000504          0.000786             0.004454
# 4  2017           0.000974          0.001581             0.004037
# 5  2018           0.001640          0.000701             0.004665
# 6  2019           0.000516          0.000432             0.003109
#
#    IntraDay_2_RF_A_k_2  IntraDay_2_RF_A_k_3  IntraDay_2_RF_A_k_4  \
# 0             0.010707             0.009543             0.008669
# 1             0.011805             0.010520             0.009044
# 2             0.009752             0.007540             0.007572
# 3             0.004531             0.004083             0.004249
# 4             0.004804             0.005030             0.004324
# ...

# %%
#Bar Graph

# %%
df.plot(figsize=(15,7), x="year", y=["IntraDay_1_RF_k_5","NextDay_1_RF_k_5","IntraDay_2_RF_A_k_1","IntraDay_2_RF_A_k_2","IntraDay_2_RF_A_k_3","IntraDay_2_RF_A_k_4","IntraDay_2_RF_A_k_5","IntraDay_2_RF_A_k_6","IntraDay_2_RF_A_k_7","IntraDay_2_RF_A_k_8","IntraDay_2_RF_B_k_5", "IntraDay_2_RF_C_k_5","Intraday_3_RF_k_1","Intraday_3_RF_k_2","Intraday_3_RF_k_3","Intraday_3_RF_k_4","Intraday_3_RF_k_5","Intraday_3_RF_k_6","Intraday_3_RF_k_7","Intraday_3_RF_k_8","IntraDay_4_RF_k_5"], kind="bar")

# %%
#Normal graph

# %%
fig = plt.figure(figsize=(16,7))
ax1 = plt.subplot(111)


# 1 rf wale
ax1.plot(df.year, df.IntraDay_1_RF_k_5,'1:')
ax1.plot(df.year, df.NextDay_1_RF_k_5,'*-')


# 2 RF wale
ax1.plot(df.year, df.IntraDay_2_RF_A_k_1,'b-')
ax1.plot(df.year, df.IntraDay_2_RF_A_k_2,'g--')
ax1.plot(df.year, df.IntraDay_2_RF_A_k_3,'r-.')
ax1.plot(df.year, df.IntraDay_2_RF_A_k_4,'c:')
ax1.plot(df.year, df.IntraDay_2_RF_A_k_5,'m--')
ax1.plot(df.year, df.IntraDay_2_RF_A_k_6,'y:')
ax1.plot(df.year, df.IntraDay_2_RF_A_k_7,'k-')
ax1.plot(df.year, df.IntraDay_2_RF_A_k_8,'r-')


# 3 RF wale
ax1.plot(df.year, df.Intraday_3_RF_k_1,'1:')
ax1.plot(df.year, df.Intraday_3_RF_k_2,'2:')
ax1.plot(df.year, df.Intraday_3_RF_k_3,'3:')
ax1.plot(df.year, df.Intraday_3_RF_k_4,'4:')
ax1.plot(df.year, df.Intraday_3_RF_k_5,'8:')
ax1.plot(df.year, df.Intraday_3_RF_k_6,'s-.')
ax1.plot(df.year, df.Intraday_3_RF_k_7,'D-.')
ax1.plot(df.year, df.Intraday_3_RF_k_8,'d-.')


# 4 RF wale
ax1.plot(df.year, df.IntraDay_4_RF_k_5,'r-')




#setting boundaries
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_color('gray')
ax1.spines['bottom'].set_color('gray')
#setting boundaries done



# ax1.legend(loc='best')
# ax1.legend(['IntraDay_1_RF-k=5','NextDay_1_RF', 'IntraDay_2_RF_A','IntraDay_2_RF_B','IntraDay_2_RF_C','IntraDay_3_RF','IntraDay_4_RF'],bbox_to_anchor=(1.25, 1.25), ncol=4)
ax1.legend(['IntraDay_1_RF_k_5','NextDay_1_RF_k_5','IntraDay_2_RF_A_k_1','IntraDay_2_RF_A_k_2','IntraDay_2_RF_A_k_3','IntraDay_2_RF_A_k_4','IntraDay_2_RF_A_k_5','IntraDay_2_RF_A_k_6','IntraDay_2_RF_A_k_7','IntraDay_2_RF_A_k_8','Intraday_3_RF_k_1','Intraday_3_RF_k_2','Intraday_3_RF_k_3','Intraday_3_RF_k_4','Intraday_3_RF_k_5','Intraday_3_RF_k_6','Intraday_3_RF_k_7','Intraday_3_RF_k_8','IntraDay_4_RF_k_5'],bbox_to_anchor=(1, 1), ncol=3)



plt.show()

# %%
# we will choose some specific model

# %%
df.plot(figsize=(15,7), x="year", y=["IntraDay_2_RF_A_k_1","IntraDay_2_RF_A_k_2","IntraDay_2_RF_A_k_3","IntraDay_2_RF_A_k_4","IntraDay_2_RF_A_k_5","IntraDay_2_RF_B_k_5","Intraday_3_RF_k_1","Intraday_3_RF_k_2","Intraday_3_RF_k_3","Intraday_3_RF_k_4","Intraday_3_RF_k_5"], kind="bar")

# %%
fig = plt.figure(figsize=(13,6))
ax1 = plt.subplot(111)




# 2 RF wale
ax1.plot(df.year, df.IntraDay_2_RF_A_k_1,'b-')
ax1.plot(df.year, df.IntraDay_2_RF_A_k_2,'g--')
ax1.plot(df.year, df.IntraDay_2_RF_A_k_3,'r-.')
ax1.plot(df.year, df.IntraDay_2_RF_A_k_4,'c:')
ax1.plot(df.year, df.IntraDay_2_RF_A_k_5,'m--')


# 3 RF wale
ax1.plot(df.year, df.Intraday_3_RF_k_1,'1:')
ax1.plot(df.year, df.Intraday_3_RF_k_2,'2:')
ax1.plot(df.year, df.Intraday_3_RF_k_3,'3:')
ax1.plot(df.year, df.Intraday_3_RF_k_4,'4:')
ax1.plot(df.year, df.Intraday_3_RF_k_5,'8:')

# 4 RF wale
ax1.plot(df.year, df.IntraDay_4_RF_k_5,'r-')




#setting boundaries
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_color('gray')
ax1.spines['bottom'].set_color('gray')
#setting boundaries done



# ax1.legend(loc='best')
# ax1.legend(['IntraDay_1_RF-k=5','NextDay_1_RF', 'IntraDay_2_RF_A','IntraDay_2_RF_B','IntraDay_2_RF_C','IntraDay_3_RF','IntraDay_4_RF'],bbox_to_anchor=(1.25, 1.25), ncol=4)
ax1.legend(['IntraDay_2_RF_A_k_1','IntraDay_2_RF_A_k_2','IntraDay_2_RF_A_k_3','IntraDay_2_RF_A_k_4','IntraDay_2_RF_A_k_5','Intraday_3_RF_k_1','Intraday_3_RF_k_2','Intraday_3_RF_k_3','Intraday_3_RF_k_4','Intraday_3_RF_k_5'],bbox_to_anchor=(1, 1), ncol=3)



plt.show()
